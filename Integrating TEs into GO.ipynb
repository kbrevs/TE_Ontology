# %% [raw]
# What do we need this to do.
#
# Option 1: The scientist chooses the distance of relevance.
# 1) Take the table of interactions.
# 2) For each interaction, select the GO term.
# 3) For that GO term, add 1 interaction to the GO dict structure, corresponding to the type of TE.
# 4) For each parent term of that GO term, populate that same interaction.

# %%
import networkx
import matplotlib
import obonet
import csv
# %matplotlib inline
from itertools import chain

# %%
#import the csv as a list of dictionaries
with open('AGLA_test_100.csv') as file:
     interaction_list = [{k: v for k, v in row.items()}
          for row in csv.DictReader(file, skipinitialspace=True)]

# %%
interaction_list
# Out:
# [{'GO_term': 'GO:0003677',
#   'GO_terms': 'GO:0003677',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'DNA binding',
#   'gene_name': 'AGLA000006',
#   'go_info': 'Any molecular function by which a gene product interacts selectively and non-covalently with DNA (deoxyribonucleic acid).',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '-',
#   'more_info': 'NA',
#   'more_math': '+',
#   'name': 'NA',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '37',
#   'ontology': 'molecular_function',
#   'other_go_term': 'GO:0043566',
#   'score': '15.8',
#   'start': '194896',
#   'stop': '201012',
#   'te_name': 'NA',
#   'te_start': '199138',
#   'te_stop': '199174',
#   'te_type': '(TTTTA)n',
#   'term_': 'GO:0003676 (nucleic acid binding)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'microtubule/chromatin interaction(RELATED)|plasmid binding(NARROW)|structure specific DNA binding(RELATED)|structure-specific DNA binding(RELATED)'},
#  {'GO_term': 'GO:0003677',
#   'GO_terms': 'GO:0003677',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'DNA binding',
#   'gene_name': 'AGLA000006',
#   'go_info': 'Any molecular function by which a gene product interacts selectively and non-covalently with DNA (deoxyribonucleic acid).',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '-',
#   'more_info': 'NA',
#   'more_math': '+',
#   'name': 'Josh',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '363',
#   'ontology': 'molecular_function',
#   'other_go_term': 'GO:0043566',
#   'score': '9.4',
#   'start': '194896',
#   'stop': '201012',
#   'te_name': 'Unknown',
#   'te_start': '199554',
#   'te_stop': '199916',
#   'te_type': 'rnd-5_family-1174',
#   'term_': 'GO:0003676 (nucleic acid binding)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'microtubule/chromatin interaction(RELATED)|plasmid binding(NARROW)|structure specific DNA binding(RELATED)|structure-specific DNA binding(RELATED)'},
#  {'GO_term': 'GO:0003677',
#   'GO_terms': 'GO:0003677',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'DNA binding',
#   'gene_name': 'AGLA000006',
#   'go_info': 'Any molecular function by which a gene product interacts selectively and non-covalently with DNA (deoxyribonucleic acid).',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '-',
#   'more_info': 'NA',
#   'more_math': '-',
#   'name': 'Josh',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '141',
#   'ontology': 'molecular_function',
#   'other_go_term': 'GO:0043566',
#   'score': '6.4',
#   'start': '194896',
#   'stop': '201012',
#   'te_name': 'Unknown',
#   'te_start': '200574',
#   'te_stop': '200714',
#   'te_type': 'rnd-5_family-1174',
#   'term_': 'GO:0003676 (nucleic acid binding)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'microtubule/chromatin interaction(RELATED)|plasmid binding(NARROW)|structure specific DNA binding(RELATED)|structure-specific DNA binding(RELATED)'},
#  {'GO_term': 'GO:0003677',
#   'GO_terms': 'GO:0003677',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'DNA binding',
#   'gene_name': 'AGLA000006',
#   'go_info': 'Any molecular function by which a gene product interacts selectively and non-covalently with DNA (deoxyribonucleic acid).',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '-',
#   'more_info': 'NA',
#   'more_math': '+',
#   'name': 'NA',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '39',
#   'ontology': 'molecular_function',
#   'other_go_term': 'GO:0043566',
#   'score': '20.7',
#   'start': '194896',
#   'stop': '201012',
#   'te_name': 'NA',
#   'te_start': '200793',
#   'te_stop': '200831',
#   'te_type': 'A-rich',
#   'term_': 'GO:0003676 (nucleic acid binding)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'microtubule/chromatin interaction(RELATED)|plasmid binding(NARROW)|structure specific DNA binding(RELATED)|structure-specific DNA binding(RELATED)'},
#  {'GO_term': 'GO:0003677',
#   'GO_terms': 'GO:0003677',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'DNA binding',
#   'gene_name': 'AGLA000006',
#   'go_info': 'Any molecular function by which a gene product interacts selectively and non-covalently with DNA (deoxyribonucleic acid).',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '-',
#   'more_info': 'NA',
#   'more_math': '+',
#   'name': 'NA',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '33',
#   'ontology': 'molecular_function',
#   'other_go_term': 'GO:0043566',
#   'score': '30.7',
#   'start': '194896',
#   'stop': '201012',
#   'te_name': 'NA',
#   'te_start': '200832',
#   'te_stop': '200864',
#   'te_type': '(TTTTCAT)n',
#   'term_': 'GO:0003676 (nucleic acid binding)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'microtubule/chromatin interaction(RELATED)|plasmid binding(NARROW)|structure specific DNA binding(RELATED)|structure-specific DNA binding(RELATED)'},
#  {'GO_term': 'GO:0003723',
#   'GO_terms': 'GO:0003723,GO:0006397,GO:0005634,GO:0005737',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'RNA binding',
#   'gene_name': 'AGLA000012',
#   'go_info': 'Interacting selectively and non-covalently with an RNA molecule or a portion thereof.',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '+',
#   'more_info': 'Reactome:REACT_101703 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Xenopus tropicalis"|Reactome:REACT_103323 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Dictyostelium discoideum"|Reactome:REACT_106430 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Mus musculus"|Reactome:REACT_107757 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Drosophila melanogaster"|Reactome:REACT_108232 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Oryza sativa"|Reactome:REACT_108368 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Saccharomyces cerevisiae"|Reactome:REACT_109723 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Arabidopsis thaliana"|Reactome:REACT_12458 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Homo sapiens"|Reactome:REACT_29965 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Canis familiaris"|Reactome:REACT_77167 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Gallus gallus"|Reactome:REACT_78197 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Sus scrofa"|Reactome:REACT_87164 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Schizosaccharomyces pombe"|Reactome:REACT_89329 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Rattus norvegicus"|Reactome:REACT_90531 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Danio rerio"|Reactome:REACT_98683 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Taeniopygia guttata"',
#   'more_math': '+',
#   'name': 'NA',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '45',
#   'ontology': 'molecular_function',
#   'other_go_term': 'GO:0044822',
#   'score': '16.3',
#   'start': '468106',
#   'stop': '492088',
#   'te_name': 'NA',
#   'te_start': '468171',
#   'te_stop': '468215',
#   'te_type': '(TAT)n',
#   'term_': 'GO:0003676 (nucleic acid binding)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'poly(A) RNA binding(RELATED)|poly(A)-RNA binding(RELATED)|poly-A RNA binding(RELATED)'},
#  {'GO_term': 'GO:0003723',
#   'GO_terms': 'GO:0003723,GO:0006397,GO:0005634,GO:0005737',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'RNA binding',
#   'gene_name': 'AGLA000012',
#   'go_info': 'Interacting selectively and non-covalently with an RNA molecule or a portion thereof.',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '+',
#   'more_info': 'Reactome:REACT_101703 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Xenopus tropicalis"|Reactome:REACT_103323 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Dictyostelium discoideum"|Reactome:REACT_106430 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Mus musculus"|Reactome:REACT_107757 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Drosophila melanogaster"|Reactome:REACT_108232 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Oryza sativa"|Reactome:REACT_108368 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Saccharomyces cerevisiae"|Reactome:REACT_109723 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Arabidopsis thaliana"|Reactome:REACT_12458 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Homo sapiens"|Reactome:REACT_29965 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Canis familiaris"|Reactome:REACT_77167 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Gallus gallus"|Reactome:REACT_78197 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Sus scrofa"|Reactome:REACT_87164 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Schizosaccharomyces pombe"|Reactome:REACT_89329 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Rattus norvegicus"|Reactome:REACT_90531 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Danio rerio"|Reactome:REACT_98683 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Taeniopygia guttata"',
#   'more_math': '+',
#   'name': 'NA',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '22',
#   'ontology': 'molecular_function',
#   'other_go_term': 'GO:0044822',
#   'score': '4.8',
#   'start': '468106',
#   'stop': '492088',
#   'te_name': 'NA',
#   'te_start': '471177',
#   'te_stop': '471198',
#   'te_type': '(TTA)n',
#   'term_': 'GO:0003676 (nucleic acid binding)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'poly(A) RNA binding(RELATED)|poly(A)-RNA binding(RELATED)|poly-A RNA binding(RELATED)'},
#  {'GO_term': 'GO:0003723',
#   'GO_terms': 'GO:0003723,GO:0006397,GO:0005634,GO:0005737',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'RNA binding',
#   'gene_name': 'AGLA000012',
#   'go_info': 'Interacting selectively and non-covalently with an RNA molecule or a portion thereof.',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '+',
#   'more_info': 'Reactome:REACT_101703 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Xenopus tropicalis"|Reactome:REACT_103323 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Dictyostelium discoideum"|Reactome:REACT_106430 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Mus musculus"|Reactome:REACT_107757 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Drosophila melanogaster"|Reactome:REACT_108232 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Oryza sativa"|Reactome:REACT_108368 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Saccharomyces cerevisiae"|Reactome:REACT_109723 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Arabidopsis thaliana"|Reactome:REACT_12458 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Homo sapiens"|Reactome:REACT_29965 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Canis familiaris"|Reactome:REACT_77167 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Gallus gallus"|Reactome:REACT_78197 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Sus scrofa"|Reactome:REACT_87164 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Schizosaccharomyces pombe"|Reactome:REACT_89329 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Rattus norvegicus"|Reactome:REACT_90531 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Danio rerio"|Reactome:REACT_98683 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Taeniopygia guttata"',
#   'more_math': '+',
#   'name': 'Dominick',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '525',
#   'ontology': 'molecular_function',
#   'other_go_term': 'GO:0044822',
#   'score': '1.5',
#   'start': '468106',
#   'stop': '492088',
#   'te_name': 'Unknown',
#   'te_start': '471773',
#   'te_stop': '472297',
#   'te_type': 'rnd-6_family-2922',
#   'term_': 'GO:0003676 (nucleic acid binding)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'poly(A) RNA binding(RELATED)|poly(A)-RNA binding(RELATED)|poly-A RNA binding(RELATED)'},
#  {'GO_term': 'GO:0003723',
#   'GO_terms': 'GO:0003723,GO:0006397,GO:0005634,GO:0005737',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'RNA binding',
#   'gene_name': 'AGLA000012',
#   'go_info': 'Interacting selectively and non-covalently with an RNA molecule or a portion thereof.',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '+',
#   'more_info': 'Reactome:REACT_101703 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Xenopus tropicalis"|Reactome:REACT_103323 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Dictyostelium discoideum"|Reactome:REACT_106430 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Mus musculus"|Reactome:REACT_107757 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Drosophila melanogaster"|Reactome:REACT_108232 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Oryza sativa"|Reactome:REACT_108368 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Saccharomyces cerevisiae"|Reactome:REACT_109723 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Arabidopsis thaliana"|Reactome:REACT_12458 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Homo sapiens"|Reactome:REACT_29965 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Canis familiaris"|Reactome:REACT_77167 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Gallus gallus"|Reactome:REACT_78197 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Sus scrofa"|Reactome:REACT_87164 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Schizosaccharomyces pombe"|Reactome:REACT_89329 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Rattus norvegicus"|Reactome:REACT_90531 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Danio rerio"|Reactome:REACT_98683 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Taeniopygia guttata"',
#   'more_math': '+',
#   'name': 'Tommy',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '289',
#   'ontology': 'molecular_function',
#   'other_go_term': 'GO:0044822',
#   'score': '20.6',
#   'start': '468106',
#   'stop': '492088',
#   'te_name': 'Unknown',
#   'te_start': '473297',
#   'te_stop': '473585',
#   'te_type': 'rnd-6_family-1697',
#   'term_': 'GO:0003676 (nucleic acid binding)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'poly(A) RNA binding(RELATED)|poly(A)-RNA binding(RELATED)|poly-A RNA binding(RELATED)'},
#  {'GO_term': 'GO:0003723',
#   'GO_terms': 'GO:0003723,GO:0006397,GO:0005634,GO:0005737',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'RNA binding',
#   'gene_name': 'AGLA000012',
#   'go_info': 'Interacting selectively and non-covalently with an RNA molecule or a portion thereof.',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '+',
#   'more_info': 'Reactome:REACT_101703 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Xenopus tropicalis"|Reactome:REACT_103323 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Dictyostelium discoideum"|Reactome:REACT_106430 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Mus musculus"|Reactome:REACT_107757 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Drosophila melanogaster"|Reactome:REACT_108232 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Oryza sativa"|Reactome:REACT_108368 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Saccharomyces cerevisiae"|Reactome:REACT_109723 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Arabidopsis thaliana"|Reactome:REACT_12458 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Homo sapiens"|Reactome:REACT_29965 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Canis familiaris"|Reactome:REACT_77167 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Gallus gallus"|Reactome:REACT_78197 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Sus scrofa"|Reactome:REACT_87164 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Schizosaccharomyces pombe"|Reactome:REACT_89329 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Rattus norvegicus"|Reactome:REACT_90531 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Danio rerio"|Reactome:REACT_98683 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Taeniopygia guttata"',
#   'more_math': '-',
#   'name': 'Herbert',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '283',
#   'ontology': 'molecular_function',
#   'other_go_term': 'GO:0044822',
#   'score': '14.0',
#   'start': '468106',
#   'stop': '492088',
#   'te_name': 'DNA/TcMar-Mariner',
#   'te_start': '475751',
#   'te_stop': '476033',
#   'te_type': 'rnd-3_family-174',
#   'term_': 'GO:0003676 (nucleic acid binding)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'poly(A) RNA binding(RELATED)|poly(A)-RNA binding(RELATED)|poly-A RNA binding(RELATED)'},
#  {'GO_term': 'GO:0003723',
#   'GO_terms': 'GO:0003723,GO:0006397,GO:0005634,GO:0005737',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'RNA binding',
#   'gene_name': 'AGLA000012',
#   'go_info': 'Interacting selectively and non-covalently with an RNA molecule or a portion thereof.',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '+',
#   'more_info': 'Reactome:REACT_101703 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Xenopus tropicalis"|Reactome:REACT_103323 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Dictyostelium discoideum"|Reactome:REACT_106430 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Mus musculus"|Reactome:REACT_107757 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Drosophila melanogaster"|Reactome:REACT_108232 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Oryza sativa"|Reactome:REACT_108368 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Saccharomyces cerevisiae"|Reactome:REACT_109723 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Arabidopsis thaliana"|Reactome:REACT_12458 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Homo sapiens"|Reactome:REACT_29965 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Canis familiaris"|Reactome:REACT_77167 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Gallus gallus"|Reactome:REACT_78197 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Sus scrofa"|Reactome:REACT_87164 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Schizosaccharomyces pombe"|Reactome:REACT_89329 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Rattus norvegicus"|Reactome:REACT_90531 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Danio rerio"|Reactome:REACT_98683 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Taeniopygia guttata"',
#   'more_math': '-',
#   'name': 'Herbert',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '262',
#   'ontology': 'molecular_function',
#   'other_go_term': 'GO:0044822',
#   'score': '21.3',
#   'start': '468106',
#   'stop': '492088',
#   'te_name': 'DNA/TcMar-Mariner',
#   'te_start': '476038',
#   'te_stop': '476299',
#   'te_type': 'rnd-3_family-174',
#   'term_': 'GO:0003676 (nucleic acid binding)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'poly(A) RNA binding(RELATED)|poly(A)-RNA binding(RELATED)|poly-A RNA binding(RELATED)'},
#  {'GO_term': 'GO:0003723',
#   'GO_terms': 'GO:0003723,GO:0006397,GO:0005634,GO:0005737',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'RNA binding',
#   'gene_name': 'AGLA000012',
#   'go_info': 'Interacting selectively and non-covalently with an RNA molecule or a portion thereof.',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '+',
#   'more_info': 'Reactome:REACT_101703 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Xenopus tropicalis"|Reactome:REACT_103323 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Dictyostelium discoideum"|Reactome:REACT_106430 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Mus musculus"|Reactome:REACT_107757 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Drosophila melanogaster"|Reactome:REACT_108232 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Oryza sativa"|Reactome:REACT_108368 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Saccharomyces cerevisiae"|Reactome:REACT_109723 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Arabidopsis thaliana"|Reactome:REACT_12458 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Homo sapiens"|Reactome:REACT_29965 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Canis familiaris"|Reactome:REACT_77167 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Gallus gallus"|Reactome:REACT_78197 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Sus scrofa"|Reactome:REACT_87164 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Schizosaccharomyces pombe"|Reactome:REACT_89329 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Rattus norvegicus"|Reactome:REACT_90531 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Danio rerio"|Reactome:REACT_98683 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Taeniopygia guttata"',
#   'more_math': '+',
#   'name': 'Wilber',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '56',
#   'ontology': 'molecular_function',
#   'other_go_term': 'GO:0044822',
#   'score': '21.4',
#   'start': '468106',
#   'stop': '492088',
#   'te_name': 'Unknown',
#   'te_start': '476363',
#   'te_stop': '476418',
#   'te_type': 'rnd-5_family-4133',
#   'term_': 'GO:0003676 (nucleic acid binding)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'poly(A) RNA binding(RELATED)|poly(A)-RNA binding(RELATED)|poly-A RNA binding(RELATED)'},
#  {'GO_term': 'GO:0003723',
#   'GO_terms': 'GO:0003723,GO:0006397,GO:0005634,GO:0005737',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'RNA binding',
#   'gene_name': 'AGLA000012',
#   'go_info': 'Interacting selectively and non-covalently with an RNA molecule or a portion thereof.',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '+',
#   'more_info': 'Reactome:REACT_101703 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Xenopus tropicalis"|Reactome:REACT_103323 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Dictyostelium discoideum"|Reactome:REACT_106430 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Mus musculus"|Reactome:REACT_107757 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Drosophila melanogaster"|Reactome:REACT_108232 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Oryza sativa"|Reactome:REACT_108368 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Saccharomyces cerevisiae"|Reactome:REACT_109723 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Arabidopsis thaliana"|Reactome:REACT_12458 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Homo sapiens"|Reactome:REACT_29965 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Canis familiaris"|Reactome:REACT_77167 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Gallus gallus"|Reactome:REACT_78197 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Sus scrofa"|Reactome:REACT_87164 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Schizosaccharomyces pombe"|Reactome:REACT_89329 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Rattus norvegicus"|Reactome:REACT_90531 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Danio rerio"|Reactome:REACT_98683 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Taeniopygia guttata"',
#   'more_math': '-',
#   'name': 'Herbert',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '184',
#   'ontology': 'molecular_function',
#   'other_go_term': 'GO:0044822',
#   'score': '22.1',
#   'start': '468106',
#   'stop': '492088',
#   'te_name': 'DNA/TcMar-Mariner',
#   'te_start': '477632',
#   'te_stop': '477815',
#   'te_type': 'rnd-3_family-174',
#   'term_': 'GO:0003676 (nucleic acid binding)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'poly(A) RNA binding(RELATED)|poly(A)-RNA binding(RELATED)|poly-A RNA binding(RELATED)'},
#  {'GO_term': 'GO:0003723',
#   'GO_terms': 'GO:0003723,GO:0006397,GO:0005634,GO:0005737',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'RNA binding',
#   'gene_name': 'AGLA000012',
#   'go_info': 'Interacting selectively and non-covalently with an RNA molecule or a portion thereof.',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '+',
#   'more_info': 'Reactome:REACT_101703 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Xenopus tropicalis"|Reactome:REACT_103323 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Dictyostelium discoideum"|Reactome:REACT_106430 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Mus musculus"|Reactome:REACT_107757 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Drosophila melanogaster"|Reactome:REACT_108232 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Oryza sativa"|Reactome:REACT_108368 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Saccharomyces cerevisiae"|Reactome:REACT_109723 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Arabidopsis thaliana"|Reactome:REACT_12458 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Homo sapiens"|Reactome:REACT_29965 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Canis familiaris"|Reactome:REACT_77167 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Gallus gallus"|Reactome:REACT_78197 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Sus scrofa"|Reactome:REACT_87164 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Schizosaccharomyces pombe"|Reactome:REACT_89329 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Rattus norvegicus"|Reactome:REACT_90531 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Danio rerio"|Reactome:REACT_98683 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Taeniopygia guttata"',
#   'more_math': '+',
#   'name': 'NA',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '30',
#   'ontology': 'molecular_function',
#   'other_go_term': 'GO:0044822',
#   'score': '19.2',
#   'start': '468106',
#   'stop': '492088',
#   'te_name': 'NA',
#   'te_start': '478028',
#   'te_stop': '478057',
#   'te_type': '(T)n',
#   'term_': 'GO:0003676 (nucleic acid binding)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'poly(A) RNA binding(RELATED)|poly(A)-RNA binding(RELATED)|poly-A RNA binding(RELATED)'},
#  {'GO_term': 'GO:0003723',
#   'GO_terms': 'GO:0003723,GO:0006397,GO:0005634,GO:0005737',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'RNA binding',
#   'gene_name': 'AGLA000012',
#   'go_info': 'Interacting selectively and non-covalently with an RNA molecule or a portion thereof.',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '+',
#   'more_info': 'Reactome:REACT_101703 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Xenopus tropicalis"|Reactome:REACT_103323 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Dictyostelium discoideum"|Reactome:REACT_106430 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Mus musculus"|Reactome:REACT_107757 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Drosophila melanogaster"|Reactome:REACT_108232 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Oryza sativa"|Reactome:REACT_108368 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Saccharomyces cerevisiae"|Reactome:REACT_109723 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Arabidopsis thaliana"|Reactome:REACT_12458 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Homo sapiens"|Reactome:REACT_29965 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Canis familiaris"|Reactome:REACT_77167 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Gallus gallus"|Reactome:REACT_78197 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Sus scrofa"|Reactome:REACT_87164 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Schizosaccharomyces pombe"|Reactome:REACT_89329 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Rattus norvegicus"|Reactome:REACT_90531 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Danio rerio"|Reactome:REACT_98683 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Taeniopygia guttata"',
#   'more_math': '-',
#   'name': 'Harley',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '121',
#   'ontology': 'molecular_function',
#   'other_go_term': 'GO:0044822',
#   'score': '27.3',
#   'start': '468106',
#   'stop': '492088',
#   'te_name': 'Unknown',
#   'te_start': '479012',
#   'te_stop': '479132',
#   'te_type': 'rnd-4_family-605',
#   'term_': 'GO:0003676 (nucleic acid binding)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'poly(A) RNA binding(RELATED)|poly(A)-RNA binding(RELATED)|poly-A RNA binding(RELATED)'},
#  {'GO_term': 'GO:0003723',
#   'GO_terms': 'GO:0003723,GO:0006397,GO:0005634,GO:0005737',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'RNA binding',
#   'gene_name': 'AGLA000012',
#   'go_info': 'Interacting selectively and non-covalently with an RNA molecule or a portion thereof.',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '+',
#   'more_info': 'Reactome:REACT_101703 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Xenopus tropicalis"|Reactome:REACT_103323 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Dictyostelium discoideum"|Reactome:REACT_106430 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Mus musculus"|Reactome:REACT_107757 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Drosophila melanogaster"|Reactome:REACT_108232 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Oryza sativa"|Reactome:REACT_108368 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Saccharomyces cerevisiae"|Reactome:REACT_109723 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Arabidopsis thaliana"|Reactome:REACT_12458 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Homo sapiens"|Reactome:REACT_29965 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Canis familiaris"|Reactome:REACT_77167 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Gallus gallus"|Reactome:REACT_78197 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Sus scrofa"|Reactome:REACT_87164 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Schizosaccharomyces pombe"|Reactome:REACT_89329 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Rattus norvegicus"|Reactome:REACT_90531 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Danio rerio"|Reactome:REACT_98683 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Taeniopygia guttata"',
#   'more_math': '+',
#   'name': 'Wilbur',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '95',
#   'ontology': 'molecular_function',
#   'other_go_term': 'GO:0044822',
#   'score': '17.4',
#   'start': '468106',
#   'stop': '492088',
#   'te_name': 'DNA/Sola',
#   'te_start': '479511',
#   'te_stop': '479605',
#   'te_type': 'rnd-4_family-701',
#   'term_': 'GO:0003676 (nucleic acid binding)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'poly(A) RNA binding(RELATED)|poly(A)-RNA binding(RELATED)|poly-A RNA binding(RELATED)'},
#  {'GO_term': 'GO:0003723',
#   'GO_terms': 'GO:0003723,GO:0006397,GO:0005634,GO:0005737',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'RNA binding',
#   'gene_name': 'AGLA000012',
#   'go_info': 'Interacting selectively and non-covalently with an RNA molecule or a portion thereof.',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '+',
#   'more_info': 'Reactome:REACT_101703 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Xenopus tropicalis"|Reactome:REACT_103323 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Dictyostelium discoideum"|Reactome:REACT_106430 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Mus musculus"|Reactome:REACT_107757 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Drosophila melanogaster"|Reactome:REACT_108232 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Oryza sativa"|Reactome:REACT_108368 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Saccharomyces cerevisiae"|Reactome:REACT_109723 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Arabidopsis thaliana"|Reactome:REACT_12458 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Homo sapiens"|Reactome:REACT_29965 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Canis familiaris"|Reactome:REACT_77167 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Gallus gallus"|Reactome:REACT_78197 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Sus scrofa"|Reactome:REACT_87164 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Schizosaccharomyces pombe"|Reactome:REACT_89329 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Rattus norvegicus"|Reactome:REACT_90531 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Danio rerio"|Reactome:REACT_98683 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Taeniopygia guttata"',
#   'more_math': '-',
#   'name': 'Wilbur',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '95',
#   'ontology': 'molecular_function',
#   'other_go_term': 'GO:0044822',
#   'score': '28.2',
#   'start': '468106',
#   'stop': '492088',
#   'te_name': 'DNA/Sola',
#   'te_start': '479964',
#   'te_stop': '480058',
#   'te_type': 'rnd-4_family-701',
#   'term_': 'GO:0003676 (nucleic acid binding)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'poly(A) RNA binding(RELATED)|poly(A)-RNA binding(RELATED)|poly-A RNA binding(RELATED)'},
#  {'GO_term': 'GO:0003723',
#   'GO_terms': 'GO:0003723,GO:0006397,GO:0005634,GO:0005737',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'RNA binding',
#   'gene_name': 'AGLA000012',
#   'go_info': 'Interacting selectively and non-covalently with an RNA molecule or a portion thereof.',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '+',
#   'more_info': 'Reactome:REACT_101703 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Xenopus tropicalis"|Reactome:REACT_103323 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Dictyostelium discoideum"|Reactome:REACT_106430 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Mus musculus"|Reactome:REACT_107757 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Drosophila melanogaster"|Reactome:REACT_108232 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Oryza sativa"|Reactome:REACT_108368 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Saccharomyces cerevisiae"|Reactome:REACT_109723 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Arabidopsis thaliana"|Reactome:REACT_12458 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Homo sapiens"|Reactome:REACT_29965 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Canis familiaris"|Reactome:REACT_77167 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Gallus gallus"|Reactome:REACT_78197 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Sus scrofa"|Reactome:REACT_87164 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Schizosaccharomyces pombe"|Reactome:REACT_89329 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Rattus norvegicus"|Reactome:REACT_90531 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Danio rerio"|Reactome:REACT_98683 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Taeniopygia guttata"',
#   'more_math': '-',
#   'name': 'Evert',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '121',
#   'ontology': 'molecular_function',
#   'other_go_term': 'GO:0044822',
#   'score': '10.8',
#   'start': '468106',
#   'stop': '492088',
#   'te_name': 'Unknown',
#   'te_start': '480280',
#   'te_stop': '480400',
#   'te_type': 'rnd-5_family-3749',
#   'term_': 'GO:0003676 (nucleic acid binding)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'poly(A) RNA binding(RELATED)|poly(A)-RNA binding(RELATED)|poly-A RNA binding(RELATED)'},
#  {'GO_term': 'GO:0003723',
#   'GO_terms': 'GO:0003723,GO:0006397,GO:0005634,GO:0005737',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'RNA binding',
#   'gene_name': 'AGLA000012',
#   'go_info': 'Interacting selectively and non-covalently with an RNA molecule or a portion thereof.',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '+',
#   'more_info': 'Reactome:REACT_101703 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Xenopus tropicalis"|Reactome:REACT_103323 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Dictyostelium discoideum"|Reactome:REACT_106430 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Mus musculus"|Reactome:REACT_107757 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Drosophila melanogaster"|Reactome:REACT_108232 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Oryza sativa"|Reactome:REACT_108368 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Saccharomyces cerevisiae"|Reactome:REACT_109723 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Arabidopsis thaliana"|Reactome:REACT_12458 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Homo sapiens"|Reactome:REACT_29965 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Canis familiaris"|Reactome:REACT_77167 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Gallus gallus"|Reactome:REACT_78197 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Sus scrofa"|Reactome:REACT_87164 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Schizosaccharomyces pombe"|Reactome:REACT_89329 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Rattus norvegicus"|Reactome:REACT_90531 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Danio rerio"|Reactome:REACT_98683 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Taeniopygia guttata"',
#   'more_math': '+',
#   'name': 'Harley',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '323',
#   'ontology': 'molecular_function',
#   'other_go_term': 'GO:0044822',
#   'score': '29.1',
#   'start': '468106',
#   'stop': '492088',
#   'te_name': 'Unknown',
#   'te_start': '480404',
#   'te_stop': '480726',
#   'te_type': 'rnd-4_family-605',
#   'term_': 'GO:0003676 (nucleic acid binding)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'poly(A) RNA binding(RELATED)|poly(A)-RNA binding(RELATED)|poly-A RNA binding(RELATED)'},
#  {'GO_term': 'GO:0003723',
#   'GO_terms': 'GO:0003723,GO:0006397,GO:0005634,GO:0005737',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'RNA binding',
#   'gene_name': 'AGLA000012',
#   'go_info': 'Interacting selectively and non-covalently with an RNA molecule or a portion thereof.',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '+',
#   'more_info': 'Reactome:REACT_101703 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Xenopus tropicalis"|Reactome:REACT_103323 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Dictyostelium discoideum"|Reactome:REACT_106430 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Mus musculus"|Reactome:REACT_107757 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Drosophila melanogaster"|Reactome:REACT_108232 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Oryza sativa"|Reactome:REACT_108368 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Saccharomyces cerevisiae"|Reactome:REACT_109723 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Arabidopsis thaliana"|Reactome:REACT_12458 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Homo sapiens"|Reactome:REACT_29965 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Canis familiaris"|Reactome:REACT_77167 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Gallus gallus"|Reactome:REACT_78197 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Sus scrofa"|Reactome:REACT_87164 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Schizosaccharomyces pombe"|Reactome:REACT_89329 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Rattus norvegicus"|Reactome:REACT_90531 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Danio rerio"|Reactome:REACT_98683 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Taeniopygia guttata"',
#   'more_math': '+',
#   'name': 'Emile',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '70',
#   'ontology': 'molecular_function',
#   'other_go_term': 'GO:0044822',
#   'score': '18.4',
#   'start': '468106',
#   'stop': '492088',
#   'te_name': 'Unknown',
#   'te_start': '486115',
#   'te_stop': '486184',
#   'te_type': 'rnd-5_family-2322',
#   'term_': 'GO:0003676 (nucleic acid binding)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'poly(A) RNA binding(RELATED)|poly(A)-RNA binding(RELATED)|poly-A RNA binding(RELATED)'},
#  {'GO_term': 'GO:0003723',
#   'GO_terms': 'GO:0003723,GO:0006397,GO:0005634,GO:0005737',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'RNA binding',
#   'gene_name': 'AGLA000012',
#   'go_info': 'Interacting selectively and non-covalently with an RNA molecule or a portion thereof.',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '+',
#   'more_info': 'Reactome:REACT_101703 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Xenopus tropicalis"|Reactome:REACT_103323 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Dictyostelium discoideum"|Reactome:REACT_106430 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Mus musculus"|Reactome:REACT_107757 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Drosophila melanogaster"|Reactome:REACT_108232 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Oryza sativa"|Reactome:REACT_108368 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Saccharomyces cerevisiae"|Reactome:REACT_109723 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Arabidopsis thaliana"|Reactome:REACT_12458 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Homo sapiens"|Reactome:REACT_29965 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Canis familiaris"|Reactome:REACT_77167 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Gallus gallus"|Reactome:REACT_78197 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Sus scrofa"|Reactome:REACT_87164 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Schizosaccharomyces pombe"|Reactome:REACT_89329 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Rattus norvegicus"|Reactome:REACT_90531 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Danio rerio"|Reactome:REACT_98683 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Taeniopygia guttata"',
#   'more_math': '+',
#   'name': 'Ralph',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '672',
#   'ontology': 'molecular_function',
#   'other_go_term': 'GO:0044822',
#   'score': '32.4',
#   'start': '468106',
#   'stop': '492088',
#   'te_name': 'DNA/TcMar-Tc1',
#   'te_start': '486439',
#   'te_stop': '487110',
#   'te_type': 'rnd-4_family-153',
#   'term_': 'GO:0003676 (nucleic acid binding)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'poly(A) RNA binding(RELATED)|poly(A)-RNA binding(RELATED)|poly-A RNA binding(RELATED)'},
#  {'GO_term': 'GO:0003723',
#   'GO_terms': 'GO:0003723,GO:0006397,GO:0005634,GO:0005737',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'RNA binding',
#   'gene_name': 'AGLA000012',
#   'go_info': 'Interacting selectively and non-covalently with an RNA molecule or a portion thereof.',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '+',
#   'more_info': 'Reactome:REACT_101703 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Xenopus tropicalis"|Reactome:REACT_103323 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Dictyostelium discoideum"|Reactome:REACT_106430 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Mus musculus"|Reactome:REACT_107757 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Drosophila melanogaster"|Reactome:REACT_108232 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Oryza sativa"|Reactome:REACT_108368 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Saccharomyces cerevisiae"|Reactome:REACT_109723 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Arabidopsis thaliana"|Reactome:REACT_12458 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Homo sapiens"|Reactome:REACT_29965 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Canis familiaris"|Reactome:REACT_77167 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Gallus gallus"|Reactome:REACT_78197 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Sus scrofa"|Reactome:REACT_87164 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Schizosaccharomyces pombe"|Reactome:REACT_89329 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Rattus norvegicus"|Reactome:REACT_90531 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Danio rerio"|Reactome:REACT_98683 "Exportin-5 recognizes 3\' overhang of pre-miRNA\\, Taeniopygia guttata"',
#   'more_math': '+',
#   'name': 'Wilbur',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '49',
#   'ontology': 'molecular_function',
#   'other_go_term': 'GO:0044822',
#   'score': '14.6',
#   'start': '468106',
#   'stop': '492088',
#   'te_name': 'DNA/Sola',
#   'te_start': '487227',
#   'te_stop': '487275',
#   'te_type': 'rnd-4_family-701',
#   'term_': 'GO:0003676 (nucleic acid binding)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'poly(A) RNA binding(RELATED)|poly(A)-RNA binding(RELATED)|poly-A RNA binding(RELATED)'},
#  {'GO_term': 'GO:0003723',
#   'GO_terms': 'GO:0003723,GO:0006397,GO:0005634,GO:0005737',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'RNA binding',
#   'gene_name': 'AGLA000012',
#   'go_info': 'Interacting selectively and non-covalently with an RNA molecule or a portion thereof.',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '+',
# ...
#   'more_math': '-',
#   'name': 'Hamilton',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '674',
#   'ontology': 'molecular_function',
#   'other_go_term': 'NA',
#   'score': '4.8',
#   'start': '1271355',
#   'stop': '1304043',
#   'te_name': 'Unknown',
#   'te_start': '1293266',
#   'te_stop': '1293939',
#   'te_type': 'rnd-5_family-1175',
#   'term_': 'GO:0016765 (transferase activity, transferring alkyl or aryl (other than methyl) groups)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'adenosylmethionine synthetase activity(EXACT)|AdoMet synthetase activity(EXACT)|ATP-methionine adenosyltransferase activity(EXACT)|ATP:L-methionine S-adenosyltransferase activity(EXACT)|methionine S-adenosyltransferase activity(EXACT)|methionine-activating enzyme(RELATED)|S-adenosyl-L-methionine synthetase activity(EXACT)|S-adenosylmethionine synthase activity(EXACT)|S-adenosylmethionine synthetase activity(EXACT)'},
#  {'GO_term': 'GO:0004478',
#   'GO_terms': 'GO:0004478,GO:0006556',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'methionine adenosyltransferase activity',
#   'gene_name': 'AGLA000034',
#   'go_info': 'Catalysis of the reaction: ATP + L-methionine + H2O = phosphate + diphosphate + S-adenosyl-L-methionine.',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '+',
#   'more_info': 'EC:2.5.1.6|MetaCyc:S-ADENMETSYN-RXN|Reactome:REACT_103144 "SAM is sythesized from methionine\'s reaction with ATP\\, Gallus gallus"|Reactome:REACT_103329 "SAM is sythesized from methionine\'s reaction with ATP\\, Taeniopygia guttata"|Reactome:REACT_105520 "SAM is sythesized from methionine\'s reaction with ATP\\, Rattus norvegicus"|Reactome:REACT_115032 "SAM is sythesized from methionine\'s reaction with ATP\\, Staphylococcus aureus N315"|Reactome:REACT_32402 "SAM is sythesized from methionine\'s reaction with ATP\\, Danio rerio"|Reactome:REACT_60836 "SAM is sythesized from methionine\'s reaction with ATP\\, Bos taurus"|Reactome:REACT_6819 "SAM is sythesized from methionine\'s reaction with ATP\\, Homo sapiens"|Reactome:REACT_77762 "SAM is sythesized from methionine\'s reaction with ATP\\, Saccharomyces cerevisiae"|Reactome:REACT_77766 "SAM is sythesized from methionine\'s reaction with ATP\\, Mycobacterium tuberculosis"|Reactome:REACT_77967 "SAM is sythesized from methionine\'s reaction with ATP\\, Canis familiaris"|Reactome:REACT_87465 "SAM is sythesized from methionine\'s reaction with ATP\\, Sus scrofa"|Reactome:REACT_91839 "SAM is sythesized from methionine\'s reaction with ATP\\, Schizosaccharomyces pombe"|Reactome:REACT_92413 "SAM is sythesized from methionine\'s reaction with ATP\\, Mus musculus"|Reactome:REACT_96978 "SAM is sythesized from methionine\'s reaction with ATP\\, Xenopus tropicalis"|RHEA:21083',
#   'more_math': '-',
#   'name': 'Colin',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '55',
#   'ontology': 'molecular_function',
#   'other_go_term': 'NA',
#   'score': '14.6',
#   'start': '1271355',
#   'stop': '1304043',
#   'te_name': 'LINE/Penelope',
#   'te_start': '1297078',
#   'te_stop': '1297132',
#   'te_type': 'rnd-5_family-1180',
#   'term_': 'GO:0016765 (transferase activity, transferring alkyl or aryl (other than methyl) groups)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'adenosylmethionine synthetase activity(EXACT)|AdoMet synthetase activity(EXACT)|ATP-methionine adenosyltransferase activity(EXACT)|ATP:L-methionine S-adenosyltransferase activity(EXACT)|methionine S-adenosyltransferase activity(EXACT)|methionine-activating enzyme(RELATED)|S-adenosyl-L-methionine synthetase activity(EXACT)|S-adenosylmethionine synthase activity(EXACT)|S-adenosylmethionine synthetase activity(EXACT)'},
#  {'GO_term': 'GO:0004478',
#   'GO_terms': 'GO:0004478,GO:0006556',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'methionine adenosyltransferase activity',
#   'gene_name': 'AGLA000034',
#   'go_info': 'Catalysis of the reaction: ATP + L-methionine + H2O = phosphate + diphosphate + S-adenosyl-L-methionine.',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '+',
#   'more_info': 'EC:2.5.1.6|MetaCyc:S-ADENMETSYN-RXN|Reactome:REACT_103144 "SAM is sythesized from methionine\'s reaction with ATP\\, Gallus gallus"|Reactome:REACT_103329 "SAM is sythesized from methionine\'s reaction with ATP\\, Taeniopygia guttata"|Reactome:REACT_105520 "SAM is sythesized from methionine\'s reaction with ATP\\, Rattus norvegicus"|Reactome:REACT_115032 "SAM is sythesized from methionine\'s reaction with ATP\\, Staphylococcus aureus N315"|Reactome:REACT_32402 "SAM is sythesized from methionine\'s reaction with ATP\\, Danio rerio"|Reactome:REACT_60836 "SAM is sythesized from methionine\'s reaction with ATP\\, Bos taurus"|Reactome:REACT_6819 "SAM is sythesized from methionine\'s reaction with ATP\\, Homo sapiens"|Reactome:REACT_77762 "SAM is sythesized from methionine\'s reaction with ATP\\, Saccharomyces cerevisiae"|Reactome:REACT_77766 "SAM is sythesized from methionine\'s reaction with ATP\\, Mycobacterium tuberculosis"|Reactome:REACT_77967 "SAM is sythesized from methionine\'s reaction with ATP\\, Canis familiaris"|Reactome:REACT_87465 "SAM is sythesized from methionine\'s reaction with ATP\\, Sus scrofa"|Reactome:REACT_91839 "SAM is sythesized from methionine\'s reaction with ATP\\, Schizosaccharomyces pombe"|Reactome:REACT_92413 "SAM is sythesized from methionine\'s reaction with ATP\\, Mus musculus"|Reactome:REACT_96978 "SAM is sythesized from methionine\'s reaction with ATP\\, Xenopus tropicalis"|RHEA:21083',
#   'more_math': '+',
#   'name': 'Colin',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '124',
#   'ontology': 'molecular_function',
#   'other_go_term': 'NA',
#   'score': '14.4',
#   'start': '1271355',
#   'stop': '1304043',
#   'te_name': 'LINE/Penelope',
#   'te_start': '1297429',
#   'te_stop': '1297552',
#   'te_type': 'rnd-5_family-1180',
#   'term_': 'GO:0016765 (transferase activity, transferring alkyl or aryl (other than methyl) groups)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'adenosylmethionine synthetase activity(EXACT)|AdoMet synthetase activity(EXACT)|ATP-methionine adenosyltransferase activity(EXACT)|ATP:L-methionine S-adenosyltransferase activity(EXACT)|methionine S-adenosyltransferase activity(EXACT)|methionine-activating enzyme(RELATED)|S-adenosyl-L-methionine synthetase activity(EXACT)|S-adenosylmethionine synthase activity(EXACT)|S-adenosylmethionine synthetase activity(EXACT)'},
#  {'GO_term': 'GO:0004478',
#   'GO_terms': 'GO:0004478,GO:0006556',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'methionine adenosyltransferase activity',
#   'gene_name': 'AGLA000034',
#   'go_info': 'Catalysis of the reaction: ATP + L-methionine + H2O = phosphate + diphosphate + S-adenosyl-L-methionine.',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '+',
#   'more_info': 'EC:2.5.1.6|MetaCyc:S-ADENMETSYN-RXN|Reactome:REACT_103144 "SAM is sythesized from methionine\'s reaction with ATP\\, Gallus gallus"|Reactome:REACT_103329 "SAM is sythesized from methionine\'s reaction with ATP\\, Taeniopygia guttata"|Reactome:REACT_105520 "SAM is sythesized from methionine\'s reaction with ATP\\, Rattus norvegicus"|Reactome:REACT_115032 "SAM is sythesized from methionine\'s reaction with ATP\\, Staphylococcus aureus N315"|Reactome:REACT_32402 "SAM is sythesized from methionine\'s reaction with ATP\\, Danio rerio"|Reactome:REACT_60836 "SAM is sythesized from methionine\'s reaction with ATP\\, Bos taurus"|Reactome:REACT_6819 "SAM is sythesized from methionine\'s reaction with ATP\\, Homo sapiens"|Reactome:REACT_77762 "SAM is sythesized from methionine\'s reaction with ATP\\, Saccharomyces cerevisiae"|Reactome:REACT_77766 "SAM is sythesized from methionine\'s reaction with ATP\\, Mycobacterium tuberculosis"|Reactome:REACT_77967 "SAM is sythesized from methionine\'s reaction with ATP\\, Canis familiaris"|Reactome:REACT_87465 "SAM is sythesized from methionine\'s reaction with ATP\\, Sus scrofa"|Reactome:REACT_91839 "SAM is sythesized from methionine\'s reaction with ATP\\, Schizosaccharomyces pombe"|Reactome:REACT_92413 "SAM is sythesized from methionine\'s reaction with ATP\\, Mus musculus"|Reactome:REACT_96978 "SAM is sythesized from methionine\'s reaction with ATP\\, Xenopus tropicalis"|RHEA:21083',
#   'more_math': '+',
#   'name': 'NA',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '37',
#   'ontology': 'molecular_function',
#   'other_go_term': 'NA',
#   'score': '19.8',
#   'start': '1271355',
#   'stop': '1304043',
#   'te_name': 'NA',
#   'te_start': '1299604',
#   'te_stop': '1299640',
#   'te_type': '(ATTAA)n',
#   'term_': 'GO:0016765 (transferase activity, transferring alkyl or aryl (other than methyl) groups)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'adenosylmethionine synthetase activity(EXACT)|AdoMet synthetase activity(EXACT)|ATP-methionine adenosyltransferase activity(EXACT)|ATP:L-methionine S-adenosyltransferase activity(EXACT)|methionine S-adenosyltransferase activity(EXACT)|methionine-activating enzyme(RELATED)|S-adenosyl-L-methionine synthetase activity(EXACT)|S-adenosylmethionine synthase activity(EXACT)|S-adenosylmethionine synthetase activity(EXACT)'},
#  {'GO_term': 'GO:0004478',
#   'GO_terms': 'GO:0004478,GO:0006556',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'methionine adenosyltransferase activity',
#   'gene_name': 'AGLA000034',
#   'go_info': 'Catalysis of the reaction: ATP + L-methionine + H2O = phosphate + diphosphate + S-adenosyl-L-methionine.',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '+',
#   'more_info': 'EC:2.5.1.6|MetaCyc:S-ADENMETSYN-RXN|Reactome:REACT_103144 "SAM is sythesized from methionine\'s reaction with ATP\\, Gallus gallus"|Reactome:REACT_103329 "SAM is sythesized from methionine\'s reaction with ATP\\, Taeniopygia guttata"|Reactome:REACT_105520 "SAM is sythesized from methionine\'s reaction with ATP\\, Rattus norvegicus"|Reactome:REACT_115032 "SAM is sythesized from methionine\'s reaction with ATP\\, Staphylococcus aureus N315"|Reactome:REACT_32402 "SAM is sythesized from methionine\'s reaction with ATP\\, Danio rerio"|Reactome:REACT_60836 "SAM is sythesized from methionine\'s reaction with ATP\\, Bos taurus"|Reactome:REACT_6819 "SAM is sythesized from methionine\'s reaction with ATP\\, Homo sapiens"|Reactome:REACT_77762 "SAM is sythesized from methionine\'s reaction with ATP\\, Saccharomyces cerevisiae"|Reactome:REACT_77766 "SAM is sythesized from methionine\'s reaction with ATP\\, Mycobacterium tuberculosis"|Reactome:REACT_77967 "SAM is sythesized from methionine\'s reaction with ATP\\, Canis familiaris"|Reactome:REACT_87465 "SAM is sythesized from methionine\'s reaction with ATP\\, Sus scrofa"|Reactome:REACT_91839 "SAM is sythesized from methionine\'s reaction with ATP\\, Schizosaccharomyces pombe"|Reactome:REACT_92413 "SAM is sythesized from methionine\'s reaction with ATP\\, Mus musculus"|Reactome:REACT_96978 "SAM is sythesized from methionine\'s reaction with ATP\\, Xenopus tropicalis"|RHEA:21083',
#   'more_math': '-',
#   'name': 'Fabian',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '101',
#   'ontology': 'molecular_function',
#   'other_go_term': 'NA',
#   'score': '7.8',
#   'start': '1271355',
#   'stop': '1304043',
#   'te_name': 'Unknown',
#   'te_start': '1303943',
#   'te_stop': '1304099',
#   'te_type': 'rnd-6_family-5388',
#   'term_': 'GO:0016765 (transferase activity, transferring alkyl or aryl (other than methyl) groups)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'adenosylmethionine synthetase activity(EXACT)|AdoMet synthetase activity(EXACT)|ATP-methionine adenosyltransferase activity(EXACT)|ATP:L-methionine S-adenosyltransferase activity(EXACT)|methionine S-adenosyltransferase activity(EXACT)|methionine-activating enzyme(RELATED)|S-adenosyl-L-methionine synthetase activity(EXACT)|S-adenosylmethionine synthase activity(EXACT)|S-adenosylmethionine synthetase activity(EXACT)'},
#  {'GO_term': 'GO:0004478',
#   'GO_terms': 'GO:0004478,GO:0006556',
#   'Owner': 'I5K',
#   'Scaffold': 'Scaffold1',
#   'Scaffold_Again': 'Scaffold1',
#   'Species': 'AGLA',
#   'TE_finder': 'RepeatMasker',
#   'dot': '.',
#   'function': 'methionine adenosyltransferase activity',
#   'gene_name': 'AGLA000034',
#   'go_info': 'Catalysis of the reaction: ATP + L-methionine + H2O = phosphate + diphosphate + S-adenosyl-L-methionine.',
#   'info_type': 'similarity',
#   'lovedots': '.',
#   'maths': '+',
#   'more_info': 'EC:2.5.1.6|MetaCyc:S-ADENMETSYN-RXN|Reactome:REACT_103144 "SAM is sythesized from methionine\'s reaction with ATP\\, Gallus gallus"|Reactome:REACT_103329 "SAM is sythesized from methionine\'s reaction with ATP\\, Taeniopygia guttata"|Reactome:REACT_105520 "SAM is sythesized from methionine\'s reaction with ATP\\, Rattus norvegicus"|Reactome:REACT_115032 "SAM is sythesized from methionine\'s reaction with ATP\\, Staphylococcus aureus N315"|Reactome:REACT_32402 "SAM is sythesized from methionine\'s reaction with ATP\\, Danio rerio"|Reactome:REACT_60836 "SAM is sythesized from methionine\'s reaction with ATP\\, Bos taurus"|Reactome:REACT_6819 "SAM is sythesized from methionine\'s reaction with ATP\\, Homo sapiens"|Reactome:REACT_77762 "SAM is sythesized from methionine\'s reaction with ATP\\, Saccharomyces cerevisiae"|Reactome:REACT_77766 "SAM is sythesized from methionine\'s reaction with ATP\\, Mycobacterium tuberculosis"|Reactome:REACT_77967 "SAM is sythesized from methionine\'s reaction with ATP\\, Canis familiaris"|Reactome:REACT_87465 "SAM is sythesized from methionine\'s reaction with ATP\\, Sus scrofa"|Reactome:REACT_91839 "SAM is sythesized from methionine\'s reaction with ATP\\, Schizosaccharomyces pombe"|Reactome:REACT_92413 "SAM is sythesized from methionine\'s reaction with ATP\\, Mus musculus"|Reactome:REACT_96978 "SAM is sythesized from methionine\'s reaction with ATP\\, Xenopus tropicalis"|RHEA:21083',
#   'more_math': '-',
#   'name': 'Hamilton',
#   'no': 'NA',
#   'no_idea': 'NA',
#   'np': 'NA',
#   'number': '889',
#   'ontology': 'molecular_function',
#   'other_go_term': 'NA',
#   'score': '3.0',
#   'start': '1271355',
#   'stop': '1304043',
#   'te_name': 'Unknown',
#   'te_start': '1293936',
#   'te_stop': '1294824',
#   'te_type': 'rnd-5_family-1175',
#   'term_': 'GO:0016765 (transferase activity, transferring alkyl or aryl (other than methyl) groups)',
#   'type_of_transcript': 'gene',
#   'wha': '.',
#   'where_it_happens': 'adenosylmethionine synthetase activity(EXACT)|AdoMet synthetase activity(EXACT)|ATP-methionine adenosyltransferase activity(EXACT)|ATP:L-methionine S-adenosyltransferase activity(EXACT)|methionine S-adenosyltransferase activity(EXACT)|methionine-activating enzyme(RELATED)|S-adenosyl-L-methionine synthetase activity(EXACT)|S-adenosylmethionine synthase activity(EXACT)|S-adenosylmethionine synthetase activity(EXACT)'}]

# %%
#loading the GO network
url = 'http://purl.obolibrary.org/obo/go/go-basic.obo'
graph = obonet.read_obo(url)
#add a dictionary entry for TEs to each node
for node in graph.nodes():
    graph.node[node]['transposable_elements'] = {}

# %%
#this needs to do two things: add TE interactions to GO terms, then populate them up through the graph.
for entry in interaction_list:
    if entry["te_name"] in (graph.node[entry["GO_term"]]['transposable_elements']).keys():
        #graph.node[entry["GO_term"]]['transposable_elements'] = {entry['te_name']:1}
        graph.node[entry["GO_term"]]['transposable_elements'][entry['te_name']] = graph.node[entry["GO_term"]]['transposable_elements'][entry['te_name']] + 1
    else:
        graph.node[entry["GO_term"]]['transposable_elements'][entry['te_name']] = 1 #adding new ones
#here is for the upper level GO terms, they are ancestors.. but we use descendants for some reason    
    for higherlevelterm in networkx.descendants(graph,entry["GO_term"]): 
        #print(higherlevelterm)
        if entry["te_name"] in (graph.node[higherlevelterm]['transposable_elements']).keys():
            graph.node[higherlevelterm]['transposable_elements'][entry['te_name']] = graph.node[higherlevelterm]['transposable_elements'][entry['te_name']] + 1
        else:
            graph.node[higherlevelterm]['transposable_elements'][entry['te_name']] = 1 #adding new ones

# %%
graph.node['GO:0003723']
# Out:
# {'alt_id': ['GO:0044822'],
#  'def': '"Interacting selectively and non-covalently with an RNA molecule or a portion thereof." [GOC:jl, GOC:mah]',
#  'is_a': ['GO:0003676'],
#  'name': 'RNA binding',
#  'namespace': 'molecular_function',
#  'subset': ['goslim_agr',
#   'goslim_aspergillus',
#   'goslim_candida',
#   'goslim_chembl',
#   'goslim_generic',
#   'goslim_mouse',
#   'goslim_plant',
#   'goslim_yeast',
#   'gosubset_prok'],
#  'synonym': ['"poly(A) RNA binding" RELATED []',
#   '"poly(A)-RNA binding" RELATED []',
#   '"poly-A RNA binding" RELATED []'],
#  'transposable_elements': {'DNA/Sola': 3,
#   'DNA/TcMar-Mariner': 3,
#   'DNA/TcMar-Tc1': 1,
#   'NA': 3,
#   'Unknown': 9},
#  'xref': ['Reactome:REACT_101703 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Xenopus tropicalis"',
#   'Reactome:REACT_103323 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Dictyostelium discoideum"',
#   'Reactome:REACT_106430 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Mus musculus"',
#   'Reactome:REACT_107757 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Drosophila melanogaster"',
#   'Reactome:REACT_108232 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Oryza sativa"',
#   'Reactome:REACT_108368 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Saccharomyces cerevisiae"',
#   'Reactome:REACT_109723 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Arabidopsis thaliana"',
#   'Reactome:REACT_12458 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Homo sapiens"',
#   'Reactome:REACT_29965 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Canis familiaris"',
#   'Reactome:REACT_77167 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Gallus gallus"',
#   'Reactome:REACT_78197 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Sus scrofa"',
#   'Reactome:REACT_87164 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Schizosaccharomyces pombe"',
#   'Reactome:REACT_89329 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Rattus norvegicus"',
#   'Reactome:REACT_90531 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Danio rerio"',
#   'Reactome:REACT_98683 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Taeniopygia guttata"']}

# %%
graph.node['GO:0003723']
# Out:
# {'alt_id': ['GO:0044822'],
#  'def': '"Interacting selectively and non-covalently with an RNA molecule or a portion thereof." [GOC:jl, GOC:mah]',
#  'is_a': ['GO:0003676'],
#  'name': 'RNA binding',
#  'namespace': 'molecular_function',
#  'subset': ['goslim_agr',
#   'goslim_aspergillus',
#   'goslim_candida',
#   'goslim_chembl',
#   'goslim_generic',
#   'goslim_mouse',
#   'goslim_plant',
#   'goslim_yeast',
#   'gosubset_prok'],
#  'synonym': ['"poly(A) RNA binding" RELATED []',
#   '"poly(A)-RNA binding" RELATED []',
#   '"poly-A RNA binding" RELATED []'],
#  'transposable_elements': {'DNA/Sola': 3,
#   'DNA/TcMar-Mariner': 3,
#   'DNA/TcMar-Tc1': 1,
#   'NA': 5,
#   'Unknown': 11},
#  'xref': ['Reactome:REACT_101703 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Xenopus tropicalis"',
#   'Reactome:REACT_103323 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Dictyostelium discoideum"',
#   'Reactome:REACT_106430 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Mus musculus"',
#   'Reactome:REACT_107757 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Drosophila melanogaster"',
#   'Reactome:REACT_108232 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Oryza sativa"',
#   'Reactome:REACT_108368 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Saccharomyces cerevisiae"',
#   'Reactome:REACT_109723 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Arabidopsis thaliana"',
#   'Reactome:REACT_12458 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Homo sapiens"',
#   'Reactome:REACT_29965 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Canis familiaris"',
#   'Reactome:REACT_77167 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Gallus gallus"',
#   'Reactome:REACT_78197 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Sus scrofa"',
#   'Reactome:REACT_87164 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Schizosaccharomyces pombe"',
#   'Reactome:REACT_89329 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Rattus norvegicus"',
#   'Reactome:REACT_90531 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Danio rerio"',
#   'Reactome:REACT_98683 "Exportin-5 recognizes 3\' overhang of pre-miRNA, Taeniopygia guttata"']}

# %%
graph.node['GO:0003676']
# Out:
# {'def': '"Interacting selectively and non-covalently with any nucleic acid." [GOC:jl]',
#  'is_a': ['GO:0097159', 'GO:1901363'],
#  'name': 'nucleic acid binding',
#  'namespace': 'molecular_function',
#  'subset': ['goslim_chembl',
#   'goslim_metagenomics',
#   'goslim_pir',
#   'goslim_plant',
#   'gosubset_prok'],
#  'transposable_elements': {'DNA/Sola': 3,
#   'DNA/TcMar-Mariner': 3,
#   'DNA/TcMar-Tc1': 1,
#   'NA': 8,
#   'Unknown': 13}}

# %%
graph.node['GO:1901363']
# Out:
# {'def': '"Interacting selectively and non-covalently with heterocyclic compound." [GOC:TermGenie]',
#  'is_a': ['GO:0005488'],
#  'name': 'heterocyclic compound binding',
#  'namespace': 'molecular_function',
#  'transposable_elements': {'DNA/Sola': 3,
#   'DNA/TcMar-Mariner': 3,
#   'DNA/TcMar-Tc1': 1,
#   'NA': 8,
#   'Unknown': 13}}

# %%
graph.node['GO:0005488']
# Out:
# {'comment': "Note that this term is in the subset of terms that should not be used for direct, manual gene product annotation. Please choose a more specific child term, or request a new one if no suitable term is available. For ligands that bind to signal transducing receptors, consider the molecular function term 'receptor binding ; GO:0005102' and its children.",
#  'def': '"The selective, non-covalent, often stoichiometric, interaction of a molecule with one or more specific sites on another molecule." [GOC:ceb, GOC:mah, ISBN:0198506732]',
#  'is_a': ['GO:0003674'],
#  'name': 'binding',
#  'namespace': 'molecular_function',
#  'subset': ['gocheck_do_not_manually_annotate',
#   'goslim_pir',
#   'goslim_plant',
#   'gosubset_prok'],
#  'synonym': ['"ligand" NARROW []'],
#  'xref': ['Wikipedia:Binding_(molecular)']}

# %%
graph.node['GO:0003674']
# Out:
# {'alt_id': ['GO:0005554'],
#  'comment': "Note that, in addition to forming the root of the molecular function ontology, this term is recommended for use for the annotation of gene products whose molecular function is unknown. When this term is used for annotation, it indicates that no information was available about the molecular function of the gene product annotated as of the date the annotation was made; the evidence code ND, no data, is used to indicate this. Despite its name, this is not a type of 'function' in the sense typically defined by upper ontologies such as Basic Formal Ontology (BFO). It is instead a BFO:process carried out by a single gene product or complex.",
#  'def': '"The actions of a single gene product or complex at the molecular level consisting of a single biochemical activity or multiple causally linked biochemical activities. A given gene product may exhibit one or more molecular functions." [GOC:go_curators]',
#  'name': 'molecular_function',
#  'namespace': 'molecular_function',
#  'subset': ['goslim_aspergillus',
#   'goslim_candida',
#   'goslim_chembl',
#   'goslim_generic',
#   'goslim_metagenomics',
#   'goslim_pir',
#   'goslim_plant',
#   'goslim_yeast',
#   'gosubset_prok'],
#  'synonym': ['"molecular function" EXACT []'],
#  'transposable_elements': {'DNA': 1,
#   'DNA/Sola': 10,
#   'DNA/TcMar-Mariner': 7,
#   'DNA/TcMar-Tc1': 9,
#   'LINE/Penelope': 2,
#   'NA': 23,
#   'Unknown': 35}}

# %%
#Visualization of the small subset of the larger data, just to see, and make sure the upwards populating is working
terms = []
for entry in interaction_list:
    terms.append(entry["GO_term"])
terms = list(set(terms))
higherterms = []
for term in terms:
    higherterms.append(networkx.descendants(graph,term))
highterms = list(set(chain.from_iterable(higherterms)))
graphGOs = terms + highterms

# %%
subgraph = graph.subgraph(graphGOs)

# %%
for GO in subgraph.nodes():
    print(GO,subgraph.node[GO]['transposable_elements'])
# Out:
# GO:0000049 {'NA': 2, 'Unknown': 3}
# GO:0003674 {'NA': 23, 'Unknown': 35, 'DNA/TcMar-Mariner': 7, 'DNA/Sola': 10, 'DNA/TcMar-Tc1': 9, 'DNA': 1, 'LINE/Penelope': 2}
# GO:0003676 {'NA': 8, 'Unknown': 13, 'DNA/TcMar-Mariner': 3, 'DNA/Sola': 3, 'DNA/TcMar-Tc1': 1}
# GO:0003677 {'NA': 3, 'Unknown': 2}
# GO:0003723 {'NA': 5, 'Unknown': 11, 'DNA/TcMar-Mariner': 3, 'DNA/Sola': 3, 'DNA/TcMar-Tc1': 1}
# GO:0003755 {'NA': 2, 'Unknown': 1}
# GO:0003824 {'NA': 11, 'Unknown': 18, 'DNA/TcMar-Tc1': 8, 'DNA/Sola': 6, 'DNA': 1, 'DNA/TcMar-Mariner': 2, 'LINE/Penelope': 2}
# GO:0004478 {'Unknown': 14, 'DNA/TcMar-Tc1': 3, 'NA': 7, 'DNA/TcMar-Mariner': 2, 'DNA/Sola': 1, 'LINE/Penelope': 2}
# GO:0004871 {'DNA/TcMar-Mariner': 2, 'Unknown': 4, 'NA': 4, 'DNA/Sola': 1}
# GO:0004872 {'DNA/TcMar-Mariner': 2, 'Unknown': 4, 'NA': 4, 'DNA/Sola': 1}
# GO:0004888 {'DNA/TcMar-Mariner': 2, 'Unknown': 4, 'NA': 4, 'DNA/Sola': 1}
# GO:0004930 {'DNA/TcMar-Mariner': 2, 'Unknown': 4, 'NA': 4, 'DNA/Sola': 1}
# GO:0005488 {'NA': 8, 'Unknown': 13, 'DNA/TcMar-Mariner': 3, 'DNA/Sola': 3, 'DNA/TcMar-Tc1': 1}
# GO:0006732 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0006777 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0006793 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0006796 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0006807 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0008150 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0008152 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0008194 {'DNA/TcMar-Tc1': 5, 'DNA/Sola': 5, 'DNA': 1, 'NA': 1, 'Unknown': 3}
# GO:0008376 {'DNA/TcMar-Tc1': 5, 'DNA/Sola': 5, 'DNA': 1, 'NA': 1, 'Unknown': 3}
# GO:0009058 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0009108 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0009987 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0016491 {'NA': 1}
# GO:0016701 {'NA': 1}
# GO:0016702 {'NA': 1}
# GO:0016740 {'DNA/TcMar-Tc1': 8, 'DNA/Sola': 6, 'DNA': 1, 'NA': 8, 'Unknown': 17, 'DNA/TcMar-Mariner': 2, 'LINE/Penelope': 2}
# GO:0016757 {'DNA/TcMar-Tc1': 5, 'DNA/Sola': 5, 'DNA': 1, 'NA': 1, 'Unknown': 3}
# GO:0016758 {'DNA/TcMar-Tc1': 5, 'DNA/Sola': 5, 'DNA': 1, 'NA': 1, 'Unknown': 3}
# GO:0016765 {'Unknown': 14, 'DNA/TcMar-Tc1': 3, 'NA': 7, 'DNA/TcMar-Mariner': 2, 'DNA/Sola': 1, 'LINE/Penelope': 2}
# GO:0016853 {'NA': 2, 'Unknown': 1}
# GO:0016859 {'NA': 2, 'Unknown': 1}
# GO:0018130 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0019538 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0019637 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0019720 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0038023 {'DNA/TcMar-Mariner': 2, 'Unknown': 4, 'NA': 4, 'DNA/Sola': 1}
# GO:0043170 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0043545 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0044237 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0044238 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0044249 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0044260 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0044267 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0046483 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0051186 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0051188 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0051189 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0051213 {'NA': 1}
# GO:0060089 {'DNA/TcMar-Mariner': 2, 'Unknown': 4, 'NA': 4, 'DNA/Sola': 1}
# GO:0071704 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0090407 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:0097159 {'NA': 8, 'Unknown': 13, 'DNA/TcMar-Mariner': 3, 'DNA/Sola': 3, 'DNA/TcMar-Tc1': 1}
# GO:0099600 {'DNA/TcMar-Mariner': 2, 'Unknown': 4, 'NA': 4, 'DNA/Sola': 1}
# GO:0140096 {'NA': 2, 'Unknown': 1}
# GO:1901360 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:1901362 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:1901363 {'NA': 8, 'Unknown': 13, 'DNA/TcMar-Mariner': 3, 'DNA/Sola': 3, 'DNA/TcMar-Tc1': 1}
# GO:1901564 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:1901566 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
# GO:1901576 {'DNA/Kolobok-Hydra': 1, 'NA': 6, 'Unknown': 5}
